# %%
# %matplotlib inline
import csv
import pandas as pd
import numpy as np
import pylab as p
import matplotlib.pyplot as plt

# %%
td = pd.read_csv('../data/train.csv', header=0)
# test_data = np.loadtxt('../data/train.csv', skiprows=1)

# %%
td.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81          0       3          13     16
# 1        80          0       8          32     40
# 2        80          0       5          27     32
# 3        75          0       3          10     13
# 4        75          0       0           1      1
#
# [5 rows x 12 columns]

# %%
sd = pd.read_csv('../data/sampleSubmission.csv', header=0)

# %%
sd.head()
# Out:
#               datetime  count
# 0  2011-01-20 00:00:00      0
# 1  2011-01-20 01:00:00      0
# 2  2011-01-20 02:00:00      0
# 3  2011-01-20 03:00:00      0
# 4  2011-01-20 04:00:00      0
#
# [5 rows x 2 columns]

# %%
td.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
plt.plot([td[td.season == i]['count'].mean() for i in range(1,5)])
# Out:
# Temps means:  [77.714285714285708, 53.233644859813083, 92.560240963855421, 179.68235294117648, 204.67278287461772, 222.06203473945411, 303.19397993311037, 342.93421052631578, 294.0]

# %%
plt.plot([td[(td.temp > i) & (td.temp <=i+1)]['count'].mean() for i in range(0,4)])

# %%
print 'working: ', td[td.workingday == 1]['count'].mean()
print 'not working: ', td[td.workingday == ]['count'].mean()
# Out:
# working:  193.011872639
# not working:  188.50662061

# %%
print 'casual working: ', td[td.workingday == 1]['casual'].mean()
print 'casual not working: ', td[td.workingday == 0]['casual'].mean()
print 'registered working: ', td[td.workingday == 1]['registered'].mean()
print 'registered not working: ', td[td.workingday == 0]['registered'].mean()
# Out:
# casual working:  25.1076632488
# casual not working:  59.3082901554
# registered working:  167.90420939
# registered not working:  129.198330455
