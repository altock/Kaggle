# %%
run -n starter

# %%
data = train()
print data
# Out:
# [['1' '0' '3' ..., '' 'S' 'adult']
#  ['2' '1' '1' ..., 'C85' 'C' 'adult']
#  ['3' '1' '3' ..., '' 'S' 'adult']
#  ...,
#  ['889' '0' '3' ..., '' 'S' '']
#  ['890' '1' '1' ..., 'C148' 'C' '']
#  ['891' '0' '3' ..., '' 'Q' '']]

# %%
number_passengers = np.size(data[0::,1].astype(np.float))
number_survived = np.sum(data[0::,1].astype(np.float))
proportion_survivors = number_survived / number_passengers

# %%
women_only_stats = data[0::,4] == "female" 
men_only_stats = data[0::,4] != "female"

# %%
women_onboard = data[women_only_stats,1].astype(np.float)     
men_onboard = data[men_only_stats,1].astype(np.float)

proportion_women_survived = np.sum(women_onboard) / np.size(women_onboard)  
proportion_men_survived = np.sum(men_onboard) / np.size(men_onboard) 

print 'Proportion of women who survived is %s' % proportion_women_survived
print 'Proportion of men who survived is %s' % proportion_men_survived
# Out:
# Proportion of women who survived is 0.742038216561
# Proportion of men who survived is 0.188908145581

# %%
test()

# %%
print data[0:15,5]
# Out:
# ['22' '38' '26' '35' '35' '' '54' '2' '27' '14' '4' '58' '20' '39' '14']

# %%
type(data[0:15,5])
# Out:
# numpy.ndarray

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/train.csv', header = 0)

# %%
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
# 41           42         0       2
# 42           43         0       3
# 43           44         1       2
# 44           45         1       3
# 45           46         0       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 49           50         0       3
# 50           51         0       3
# 51           52         0       3
# 52           53         1       1
# 53           54         1       2
# 54           55         0       1
# 55           56         1       1
# 56           57         1       2
# 57           58         0       3
# 58           59         1       2
# 59           60         0       3
#             ...       ...     ...
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                Todoroff, Mr. Lalio    male   NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 32                           Glynn, Miss. Mary Agatha  female   NaN      0
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                     Holverson, Mr. Alexander Oskar    male  42.0      1
# 36                                   Mamee, Mr. Hanna    male   NaN      0
# 37                           Cann, Mr. Ernest Charles    male  21.0      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.0      2
# 39                        Nicola-Yarred, Miss. Jamila  female  14.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 42                                Kraeff, Mr. Theodor    male   NaN      0
# 43           Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 44                      Devaney, Miss. Margaret Delia  female  19.0      0
# 45                           Rogers, Mr. William John    male   NaN      0
# 46                                  Lennon, Mr. Denis    male   NaN      1
# 47                          O'Driscoll, Miss. Bridget  female   NaN      0
# 48                                Samaan, Mr. Youssef    male   NaN      2
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 50                         Panula, Master. Juha Niilo    male   7.0      4
# 51                       Nosworthy, Mr. Richard Cater    male  21.0      0
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 53  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 55                                  Woolner, Mr. Hugh    male   NaN      0
# 56                                  Rugg, Miss. Emily  female  21.0      0
# 57                                Novel, Mr. Mansouer    male  28.5      0
# 58                       West, Miss. Constance Mirium  female   5.0      1
# 59                 Goodwin, Master. William Frederick    male  11.0      5
#                                                   ...     ...   ...    ...
#
#     Parch            Ticket      Fare        Cabin Embarked Maturity
# 0       0         A/5 21171    7.2500          NaN        S    adult
# 1       0          PC 17599   71.2833          C85        C    adult
# 2       0  STON/O2. 3101282    7.9250          NaN        S    adult
# 3       0            113803   53.1000         C123        S    adult
# 4       0            373450    8.0500          NaN        S    adult
# 5       0            330877    8.4583          NaN        Q    child
# 6       0             17463   51.8625          E46        S    adult
# 7       1            349909   21.0750          NaN        S    child
# 8       2            347742   11.1333          NaN        S    adult
# 9       0            237736   30.0708          NaN        C    child
# 10      1           PP 9549   16.7000           G6        S    child
# 11      0            113783   26.5500         C103        S    adult
# 12      0         A/5. 2151    8.0500          NaN        S    adult
# 13      5            347082   31.2750          NaN        S    adult
# 14      0            350406    7.8542          NaN        S    child
# 15      0            248706   16.0000          NaN        S    adult
# 16      1            382652   29.1250          NaN        Q    child
# 17      0            244373   13.0000          NaN        S    child
# 18      0            345763   18.0000          NaN        S    adult
# 19      0              2649    7.2250          NaN        C    child
# 20      0            239865   26.0000          NaN        S    adult
# 21      0            248698   13.0000          D56        S    adult
# 22      0            330923    8.0292          NaN        Q    child
# 23      0            113788   35.5000           A6        S    adult
# 24      1            349909   21.0750          NaN        S    child
# 25      5            347077   31.3875          NaN        S    adult
# 26      0              2631    7.2250          NaN        C    child
# 27      2             19950  263.0000  C23 C25 C27        S    adult
# 28      0            330959    7.8792          NaN        Q    child
# 29      0            349216    7.8958          NaN        S    child
# 30      0          PC 17601   27.7208          NaN        C    adult
# 31      0          PC 17569  146.5208          B78        C    child
# 32      0            335677    7.7500          NaN        Q    child
# 33      0        C.A. 24579   10.5000          NaN        S    adult
# 34      0          PC 17604   82.1708          NaN        C    adult
# 35      0            113789   52.0000          NaN        S    adult
# 36      0              2677    7.2292          NaN        C    child
# 37      0        A./5. 2152    8.0500          NaN        S    adult
# 38      0            345764   18.0000          NaN        S    child
# 39      0              2651   11.2417          NaN        C    child
# 40      0              7546    9.4750          NaN        S    adult
# 41      0             11668   21.0000          NaN        S    adult
# 42      0            349253    7.8958          NaN        C    child
# 43      2     SC/Paris 2123   41.5792          NaN        C    child
# 44      0            330958    7.8792          NaN        Q    adult
# 45      0   S.C./A.4. 23567    8.0500          NaN        S    child
# 46      0            370371   15.5000          NaN        Q    child
# 47      0             14311    7.7500          NaN        Q    child
# 48      0              2662   21.6792          NaN        C    child
# 49      0            349237   17.8000          NaN        S    child
# 50      1           3101295   39.6875          NaN        S    child
# 51      0        A/4. 39886    7.8000          NaN        S    adult
# 52      0          PC 17572   76.7292          D33        C    adult
# 53      0              2926   26.0000          NaN        S    adult
# 54      1            113509   61.9792          B30        C    adult
# 55      0             19947   35.5000          C52        S    child
# 56      0        C.A. 31026   10.5000          NaN        S    adult
# 57      0              2697    7.2292          NaN        C    adult
# 58      2        C.A. 34651   27.7500          NaN        S    child
# 59      2           CA 2144   46.9000          NaN        S    child
#       ...               ...       ...          ...      ...      ...
#
# [891 rows x 13 columns]

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
#
#    Parch            Ticket     Fare Cabin Embarked Maturity
# 0      0         A/5 21171   7.2500   NaN        S    adult
# 1      0          PC 17599  71.2833   C85        C    adult
# 2      0  STON/O2. 3101282   7.9250   NaN        S    adult
#
# [3 rows x 13 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Maturity        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Maturity       61 non-null object
# dtypes: float64(2), int64(5), object(6)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df['Age'][:10]
# Out:
# 0    22
# 1    38
# 2    26
# 3    35
# 4    35
# 5   NaN
# 6    54
# 7     2
# 8    27
# 9    14
# Name: Age, dtype: float64

# %%
df.Age[:10]
# Out:
# 0    22
# 1    38
# 2    26
# 3    35
# 4    35
# 5   NaN
# 6    54
# 7     2
# 8    27
# 9    14
# Name: Age, dtype: float64

# %%
df.Cabin[:10]
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %%
type(df.Age)
# Out:
# pandas.core.series.Series

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df[['Sex', 'Pclass', 'Age']]
# Out:
#        Sex  Pclass   Age
# 0     male       3  22.0
# 1   female       1  38.0
# 2   female       3  26.0
# 3   female       1  35.0
# 4     male       3  35.0
# 5     male       3   NaN
# 6     male       1  54.0
# 7     male       3   2.0
# 8   female       3  27.0
# 9   female       2  14.0
# 10  female       3   4.0
# 11  female       1  58.0
# 12    male       3  20.0
# 13    male       3  39.0
# 14  female       3  14.0
# 15  female       2  55.0
# 16    male       3   2.0
# 17    male       2   NaN
# 18  female       3  31.0
# 19  female       3   NaN
# 20    male       2  35.0
# 21    male       2  34.0
# 22  female       3  15.0
# 23    male       1  28.0
# 24  female       3   8.0
# 25  female       3  38.0
# 26    male       3   NaN
# 27    male       1  19.0
# 28  female       3   NaN
# 29    male       3   NaN
# 30    male       1  40.0
# 31  female       1   NaN
# 32  female       3   NaN
# 33    male       2  66.0
# 34    male       1  28.0
# 35    male       1  42.0
# 36    male       3   NaN
# 37    male       3  21.0
# 38  female       3  18.0
# 39  female       3  14.0
# 40  female       3  40.0
# 41  female       2  27.0
# 42    male       3   NaN
# 43  female       2   3.0
# 44  female       3  19.0
# 45    male       3   NaN
# 46    male       3   NaN
# 47  female       3   NaN
# 48    male       3   NaN
# 49  female       3  18.0
# 50    male       3   7.0
# 51    male       3  21.0
# 52  female       1  49.0
# 53  female       2  29.0
# 54    male       1  65.0
# 55    male       1   NaN
# 56  female       2  21.0
# 57    male       3  28.5
# 58  female       2   5.0
# 59    male       3  11.0
#        ...     ...   ...
#
# [891 rows x 3 columns]

# %%
df[df.Age > 60]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 493          494         0       1                    Artagaveytia, Mr. Ramon
# 545          546         0       1               Nicholson, Mr. Arthur Ernest
# 555          556         0       1                         Wright, Mr. George
# 570          571         1       2                         Harris, Mr. George
# 625          626         0       1                      Sutton, Mr. Frederick
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2                Mitchell, Mr. Henry Michael
# 745          746         0       1               Crosby, Capt. Edward Gifford
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
# 851          852         0       3                        Svensson, Mr. Johan
#
#         Sex   Age  SibSp  Parch       Ticket      Fare        Cabin Embarked  \
# 33     male  66.0      0      0   C.A. 24579   10.5000          NaN        S
# 54     male  65.0      0      1       113509   61.9792          B30        C
# 96     male  71.0      0      0     PC 17754   34.6542           A5        C
# 116    male  70.5      0      0       370369    7.7500          NaN        Q
# 170    male  61.0      0      0       111240   33.5000          B19        S
# 252    male  62.0      0      0       113514   26.5500          C87        S
# 275  female  63.0      1      0        13502   77.9583           D7        S
# 280    male  65.0      0      0       336439    7.7500          NaN        Q
# 326    male  61.0      0      0       345364    6.2375          NaN        S
# 438    male  64.0      1      4        19950  263.0000  C23 C25 C27        S
# 456    male  65.0      0      0        13509   26.5500          E38        S
# 483  female  63.0      0      0         4134    9.5875          NaN        S
# 493    male  71.0      0      0     PC 17609   49.5042          NaN        C
# 545    male  64.0      0      0          693   26.0000          NaN        S
# 555    male  62.0      0      0       113807   26.5500          NaN        S
# 570    male  62.0      0      0  S.W./PP 752   10.5000          NaN        S
# 625    male  61.0      0      0        36963   32.3208          D50        S
# 630    male  80.0      0      0        27042   30.0000          A23        S
# 672    male  70.0      0      0   C.A. 24580   10.5000          NaN        S
# 745    male  70.0      1      1    WE/P 5735   71.0000          B22        S
# 829  female  62.0      0      0       113572   80.0000          B28      NaN
# 851    male  74.0      0      0       347060    7.7750          NaN        S
#
#     Maturity
# 33     adult
# 54     adult
# 96       NaN
# 116      NaN
# 170      NaN
# 252      NaN
# 275      NaN
# 280      NaN
# 326      NaN
# 438      NaN
# 456      NaN
# 483      NaN
# 493      NaN
# 545      NaN
# 555      NaN
# 570      NaN
# 625      NaN
# 630      NaN
# 672      NaN
# 745      NaN
# 829      NaN
# 851      NaN
#
# [22 rows x 13 columns]

# %%
df[df.Age > 60][['Sex', 'Pclass', 'Age', 'Survived']]
# Out:
#         Sex  Pclass   Age  Survived
# 33     male       2  66.0         0
# 54     male       1  65.0         0
# 96     male       1  71.0         0
# 116    male       3  70.5         0
# 170    male       1  61.0         0
# 252    male       1  62.0         0
# 275  female       1  63.0         1
# 280    male       3  65.0         0
# 326    male       3  61.0         0
# 438    male       1  64.0         0
# 456    male       1  65.0         0
# 483  female       3  63.0         1
# 493    male       1  71.0         0
# 545    male       1  64.0         0
# 555    male       1  62.0         0
# 570    male       2  62.0         1
# 625    male       1  61.0         0
# 630    male       1  80.0         1
# 672    male       2  70.0         0
# 745    male       1  70.0         0
# 829  female       1  62.0         1
# 851    male       3  74.0         0
#
# [22 rows x 4 columns]

# %%
df[df.Age.isnull()][['Sex', 'Pclass', 'Age']]
# Out:
#         Sex  Pclass  Age
# 5      male       3  NaN
# 17     male       2  NaN
# 19   female       3  NaN
# 26     male       3  NaN
# 28   female       3  NaN
# 29     male       3  NaN
# 31   female       1  NaN
# 32   female       3  NaN
# 36     male       3  NaN
# 42     male       3  NaN
# 45     male       3  NaN
# 46     male       3  NaN
# 47   female       3  NaN
# 48     male       3  NaN
# 55     male       1  NaN
# 64     male       1  NaN
# 65     male       3  NaN
# 76     male       3  NaN
# 77     male       3  NaN
# 82   female       3  NaN
# 87     male       3  NaN
# 95     male       3  NaN
# 101    male       3  NaN
# 107    male       3  NaN
# 109  female       3  NaN
# 121    male       3  NaN
# 126    male       3  NaN
# 128  female       3  NaN
# 140  female       3  NaN
# 154    male       3  NaN
# 158    male       3  NaN
# 159    male       3  NaN
# 166  female       1  NaN
# 168    male       1  NaN
# 176    male       3  NaN
# 180  female       3  NaN
# 181    male       2  NaN
# 185    male       1  NaN
# 186  female       3  NaN
# 196    male       3  NaN
# 198  female       3  NaN
# 201    male       3  NaN
# 214    male       3  NaN
# 223    male       3  NaN
# 229  female       3  NaN
# 235  female       3  NaN
# 240  female       3  NaN
# 241  female       3  NaN
# 250    male       3  NaN
# 256  female       1  NaN
# 260    male       3  NaN
# 264  female       3  NaN
# 270    male       1  NaN
# 274  female       3  NaN
# 277    male       2  NaN
# 284    male       1  NaN
# 295    male       1  NaN
# 298    male       1  NaN
# 300  female       3  NaN
# 301    male       3  NaN
#         ...     ...  ...
#
# [177 rows x 3 columns]

# %%
for i in xrange(1,4):
    print i, len(df[ (df.Sex == 'male') & (df.Pclass == i)])
# Out:
# 1 122
# 2 108
# 3 347

# %%
import pylab as p

# %%
# df.Age.hist()
# p.show()

# %%
# df.Age.dropna().hist(bins=16, range=(0,80), alpha = .55)
# p.show()

# %%
df['Gender'] = 4

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male  NaN      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# 7                     Palsson, Master. Gosta Leonard    male    2      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
#
#    Parch            Ticket     Fare Cabin Embarked Maturity  Gender
# 0      0         A/5 21171   7.2500   NaN        S    adult       4
# 1      0          PC 17599  71.2833   C85        C    adult       4
# 2      0  STON/O2. 3101282   7.9250   NaN        S    adult       4
# 3      0            113803  53.1000  C123        S    adult       4
# 4      0            373450   8.0500   NaN        S    adult       4
# 5      0            330877   8.4583   NaN        Q    child       4
# 6      0             17463  51.8625   E46        S    adult       4
# 7      1            349909  21.0750   NaN        S    child       4
# 8      2            347742  11.1333   NaN        S    adult       4
# 9      0            237736  30.0708   NaN        C    child       4
#
# [10 rows x 14 columns]

# %%
df.Gender = df.Sex.map({'female':0, 'male': 1} ).astype(int)

# %%
df.Embarked = df.Embarked.map({'C':0, 'S':1, 'Q':2})

# %%
median_ages = np.zeros((2,3))
median_ages
# Out:
# array([[ 0.,  0.,  0.],
#        [ 0.,  0.,  0.]])

# %%
for i in xrange(2):
    for j in xrange(3):
        median_ages[i,j] = df[(df.Gender == i) & (df.Pclass == j+1)]['Age'].dropna().median()
median_ages
# Out:
# array([[ 35. ,  28. ,  21.5],
#        [ 40. ,  30. ,  25. ]])

# %%
df['AgeFill'] = df.Age

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin  Embarked Maturity  Gender  AgeFill
# 0      0         A/5 21171   7.2500   NaN         1    adult       1       22
# 1      0          PC 17599  71.2833   C85         0    adult       0       38
# 2      0  STON/O2. 3101282   7.9250   NaN         1    adult       0       26
# 3      0            113803  53.1000  C123         1    adult       0       35
# 4      0            373450   8.0500   NaN         1    adult       1       35
#
# [5 rows x 15 columns]

# %%
df[df.Age.isnull()][['Gender','Pclass','Age','AgeFill']].head(10)
# Out:
#     Gender  Pclass  Age  AgeFill
# 5        1       3  NaN      NaN
# 17       1       2  NaN      NaN
# 19       0       3  NaN      NaN
# 26       1       3  NaN      NaN
# 28       0       3  NaN      NaN
# 29       1       3  NaN      NaN
# 31       0       1  NaN      NaN
# 32       0       3  NaN      NaN
# 36       1       3  NaN      NaN
# 42       1       3  NaN      NaN
#
# [10 rows x 4 columns]

# %%
for i in xrange(2):
    for j in xrange(3):
        df.loc[(df.Age.isnull()) & (df.Gender == i) & (df.Pclass == j+1), 'AgeFill'] = median_ages[i,j]

# %%
df['AgeIsNull'] = pd.isnull(df.Age).astype(int)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare    Embarked      Gender     AgeFill   AgeIsNull
# count  891.000000  891.000000  889.000000  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.897638    0.647587   29.112424    0.198653
# std      0.806057   49.693429    0.515181    0.477990   13.304424    0.399210
# min      0.000000    0.000000    0.000000    0.000000    0.420000    0.000000
# 25%      0.000000    7.910400    1.000000    0.000000   21.500000    0.000000
# 50%      0.000000   14.454200    1.000000    1.000000   26.000000    0.000000
# 75%      0.000000   31.000000    1.000000    1.000000   36.000000    0.000000
# max      6.000000  512.329200    2.000000    1.000000   80.000000    1.000000
#
# [8 rows x 11 columns]

# %%
df['FamilySize'] = df.SibSp + df.Parch

# %%
df['Age*Class'] = df.AgeFill * df.Pclass

# %%
# df['Age*Class'].dropna().hist(bins=16, range=(0,80), alpha = .55)
# p.show()

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked       float64
# Maturity        object
# Gender           int64
# AgeFill        float64
# AgeIsNull        int64
# FamilySize       int64
# Age*Class      float64
# dtype: object

# %%
df = df.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Maturity'], axis = 1)

# %%
df = df.drop(['Age'], axis=1)

# %%
df = df.dropna()
train_data = df.values
train_data
# Out:
# array([[  0. ,   3. ,   1. , ...,   0. ,   1. ,  66. ],
#        [  1. ,   1. ,   1. , ...,   0. ,   1. ,  38. ],
#        [  1. ,   3. ,   0. , ...,   0. ,   0. ,  78. ],
#        ...,
#        [  0. ,   3. ,   1. , ...,   1. ,   3. ,  64.5],
#        [  1. ,   1. ,   0. , ...,   0. ,   0. ,  26. ],
#        [  0. ,   3. ,   0. , ...,   0. ,   0. ,  96. ]])

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# SibSp            int64
# Parch            int64
# Fare           float64
# Embarked       float64
# Gender           int64
# AgeFill        float64
# AgeIsNull        int64
# FamilySize       int64
# Age*Class      float64
# dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch     Fare  Embarked  Gender  \
# 0            1         0       3      1      0   7.2500         1       1
# 1            2         1       1      1      0  71.2833         0       0
# 2            3         1       3      0      0   7.9250         1       0
# 3            4         1       1      1      0  53.1000         1       0
# 4            5         0       3      0      0   8.0500         1       1
#
#    AgeFill  AgeIsNull  FamilySize  Age*Class
# 0       22          0           1         66
# 1       38          0           1         38
# 2       26          0           0         78
# 3       35          0           1         35
# 4       35          0           0        105
#
# [5 rows x 12 columns]

# %%
df = df.drop(['PassengerId'], axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
test_data = csv.reader(open('../data/test.csv', 'rbU'))
test_data.next()
# Out:
# ['PassengerId',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
forest = RandomForestClassifier(n_estimators=100)

# %%
forest = forest.fit(train_data[0::,1::], train_data[0::,0])

# %%
output = forest.predict(test_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-374-ab67282a9878> in <module>()
# ----> 1 output = forest.predict(test_data)
#
# /home/altock/.local/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in predict(self, X)
#     459         # ensure_2d=False because there are actually unit test checking we fail
#     460         # for 1d.
# --> 461         X = check_array(X, ensure_2d=False, accept_sparse="csr")
#     462         proba = self.predict_proba(X)
#     463
#
# /home/altock/.local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features)
#     345         # make sure we actually converted to numeric:
#     346         if dtype_numeric and array.dtype.kind == "O":
# --> 347             array = array.astype(np.float64)
#     348         if not allow_nd and array.ndim >= 3:
#     349             raise ValueError("Found array with dim %d. Expected <= 2" %
#
# TypeError: float() argument must be a string or a number
